# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder


from sklearn.model_selection import train_test_split

#from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Dense

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet

from sklearn import metrics
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# %matplotlib inline
#Import the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,log_loss

import matplotlib.pyplot as plt
import datetime
from statsmodels.tsa.arima_model import ARIMA
from sklearn import metrics

import warnings
warnings.filterwarnings("ignore")


from datetime import date as dt
from datetime import datetime,timedelta

# %%
data = pd.read_csv("/content/healthcare_dataset.csv", parse_dates =True, index_col ="Discharge Date")
data
# Out:
#                              Name  Age  Gender Blood Type Medical Condition  \
# Discharge Date
# 2024-02-02          Bobby JacksOn   30    Male         B-            Cancer
# 2019-08-26           LesLie TErRy   62    Male         A+           Obesity
# 2022-10-07            DaNnY sMitH   76  Female         A-           Obesity
# 2020-12-18           andrEw waTtS   28  Female         O+          Diabetes
# 2022-10-09          adrIENNE bEll   43  Female        AB+            Cancer
# ...                           ...  ...     ...        ...               ...
# 2020-09-15      eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 2020-02-01             KYle pEREz   61  Female        AB-           Obesity
# 2020-08-10           HEATher WaNG   38  Female         B+      Hypertension
# 2019-05-31         JENniFER JOneS   43    Male         O-         Arthritis
# 2024-04-29           jAMES GARCiA   53  Female         O+         Arthritis
#
# ...

# %%
#dff = data[['Discharge Date', 'Billing Amount']]
#dff

# %%
data = data.rename({'Billing Amount': 'BillingAmount'}, axis=1)
data
# Out:
#                              Name  Age  Gender Blood Type Medical Condition  \
# Discharge Date
# 2024-02-02          Bobby JacksOn   30    Male         B-            Cancer
# 2019-08-26           LesLie TErRy   62    Male         A+           Obesity
# 2022-10-07            DaNnY sMitH   76  Female         A-           Obesity
# 2020-12-18           andrEw waTtS   28  Female         O+          Diabetes
# 2022-10-09          adrIENNE bEll   43  Female        AB+            Cancer
# ...                           ...  ...     ...        ...               ...
# 2020-09-15      eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 2020-02-01             KYle pEREz   61  Female        AB-           Obesity
# 2020-08-10           HEATher WaNG   38  Female         B+      Hypertension
# 2019-05-31         JENniFER JOneS   43    Male         O-         Arthritis
# 2024-04-29           jAMES GARCiA   53  Female         O+         Arthritis
#
# ...

# %%
monthly_resampled_data = data.BillingAmount.resample('M').mean()
monthly_resampled_data
# Out:
# Discharge Date
# 2019-05-31    25747.979412
# 2019-06-30    26237.170766
# 2019-07-31    25863.988161
# 2019-08-31    25796.331254
# 2019-09-30    24807.768097
#                   ...
# 2024-02-29    26169.101496
# 2024-03-31    25426.647369
# 2024-04-30    25299.958627
# 2024-05-31    24808.643514
# 2024-06-30    23064.444442
# Freq: ME, Name: BillingAmount, Length: 62, dtype: float64

# %%
train=monthly_resampled_data[0:40]
test=monthly_resampled_data[40:]

# %%
#Plotting data
train.plot(figsize=(10,8), title= 'Billing amount', fontsize=14)
test.plot(figsize=(10,8), title= 'Billing amount', fontsize=14)
plt.legend(['Train', 'Test'])
plt.show()

# %%
#Plotting data
monthly_resampled_data.plot(figsize=(10,6), title= 'Billing amount', fontsize=14)
# Out:
# <Axes: title={'center': 'Billing amount'}, xlabel='Discharge Date'>

# %%
train=monthly_resampled_data[0:40]
test=monthly_resampled_data[40:]

# %% [markdown]
# **Differencing:**
# Differencing can help stabilise the mean of a time series by removing changes in the level of a time series, and therefore eliminating trend and seasonality.

# %%
data_log = np.log(monthly_resampled_data)
data_diff = data_log - data_log.shift()
plt.plot(data_diff)

# %% [markdown]
# **Exponential Smoothing:**
# Exponential Smoothing Methods are a family of forecasting models. They use weighted averages of past observations to forecast new values.

# %%
from statsmodels.tsa.api import SimpleExpSmoothing,ExponentialSmoothing,Holt
# Simple Exponential Smoothing
fit = SimpleExpSmoothing(monthly_resampled_data.iloc[:40]).fit(smoothing_level=0.2,optimized=False)
fcast1 = fit.forecast(monthly_resampled_data.iloc[40:].shape[0]).rename(r'$\alpha=0.2$')
# plot
fcast1.plot(marker='o', color='blue', legend=True, ylabel= 'Billing_Amount_Exp_Smoothing')
fit.fittedvalues.plot(marker='*',  color='blue')
#plt.xlabel('Year')
#fcast1.ylabel('BillingAmount_ExpSmoothing')
# Out:
# <Axes: xlabel='Discharge Date', ylabel='Billing_Amount_Exp_Smoothing'>

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(fcast1, data_log.iloc[40:]))
print('Mean Squared Error:', metrics.mean_squared_error(fcast1, data_log.iloc[40:]))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(fcast1, data_log.iloc[40:])))
# Out:
# Mean Absolute Error: 25515.186182046364
# Mean Squared Error: 651024725.9054066
# Root Mean Squared Error: 25515.18618206433

# %% [markdown]
# **Decomposing:** In this approach, both trend and seasonality are modeled separately and the remaining part of the series is returned. I’ll skip the statistics and come to the results:

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(data_log)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(data_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Here we can see that the trend, seasonality are separated out from data and we can model the residuals. Lets check stationarity of residuals:

# %%
#ACF and PACF plots:
data_diff.dropna(inplace=True)
from statsmodels.tsa.stattools import acf, pacf
lag_acf = acf(data_diff, nlags=5)
lag_pacf = pacf(data_diff, nlags=5, method='ols')

#Plot ACF:
plt.subplot(121)
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(data_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(data_diff)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')
# Out:
# Text(0.5, 1.0, 'Autocorrelation Function')

# %% [markdown]
# p – The lag value where the PACF chart crosses the upper confidence interval for the first time.

# %%
#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(data_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(data_diff)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
# Out:
# Text(0.5, 1.0, 'Partial Autocorrelation Function')

# %%
def mape(actual,pred):
    mape = np.mean(abs((actual - pred)/actual))*100
    return mape

# %% [markdown]
# q – The lag value where the ACF chart crosses the upper confidence interval for the first time. If you notice closely, in this case q=2.

# %% [markdown]
# **ARIMA Model:**
# ARIMA stands for Auto Regressive Integrated Moving Average. There are seasonal and Non-seasonal ARIMA models that can be used for forecasting

# %%
#from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima.model import ARIMA
# !pip install statsmodels.tsa.arima.model.ARIMA
# !pip install ARIMA
model_arima = ARIMA(monthly_resampled_data.iloc[:40], order=(2, 1, 2))
results_ARIMA = model_arima.fit()
# Out:
# ERROR: Could not find a version that satisfies the requirement statsmodels.tsa.arima.model.ARIMA (from versions: none)
# ERROR: No matching distribution found for statsmodels.tsa.arima.model.ARIMA
# ERROR: Could not find a version that satisfies the requirement ARIMA (from versions: none)
# ERROR: No matching distribution found for ARIMA
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
test = monthly_resampled_data.iloc[40:]
forecaste = results_ARIMA.forecast(steps = 5)[0]
test['forecast'] = forecaste
plt.plot(monthly_resampled_data)
plt.plot(test['forecast'], color = 'red',ls = 'dashed')
#set_xlim(pd.Timestamp('2019-01-01'), pd.Timestamp('2025-01-01')) # Y-m-d
#set_ylim(20000, 30000)
plt.legend(["BillingAmount","Forecasted_BillingAmount_ARIMA"])
plt.xlabel('Year')
plt.ylabel('BillingAmount')
# Out:
# Text(0, 0.5, 'BillingAmount')

# %% [markdown]
# **Seasonal ARIMA:** An extension to ARIMA that supports the direct modeling of the seasonal component of the series is called SARIMA.

# %%
#building the model
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model_SARIMA = SARIMAX(endog=monthly_resampled_data.iloc[:40],order =(1,1,0),seasonal_order=(0,1,0,12))
results_SARIMA = model_SARIMA.fit(disp= 0)

# %%
test = monthly_resampled_data.iloc[40:]
forecaste = results_SARIMA.forecast(steps = 5)[0]
test['forecast'] = forecaste
plt.plot(monthly_resampled_data)
plt.plot(test['forecast'], color = 'red',ls = 'dashed')
plt.legend(["Billing_amount","Forecasted_billing_amount_SARIMA"])
plt.xlabel('Year')
plt.ylabel('Billing_amount')
# Out:
# Text(0, 0.5, 'Billing_amount')

# %% [markdown]
# **Auto ARIMA Model**

# %%
# !pip install pmdarima
import pmdarima
from pmdarima.arima import auto_arima

model = auto_arima(monthly_resampled_data.iloc[:40], start_p=0, start_q=0, max_p=3, max_q=2, m=12,max_P=2,d=1,
    max_D=1,max_Q=2,start_P=0, seasonal=True, trace=True,
                      error_action='ignore',
                      suppress_warnings=True,
                      stepwise=True)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 37.8 MB/s eta 0:00:00
# ...
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=635.832, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=633.863, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=636.685, Time=0.18 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=636.593, Time=0.21 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=631.865, Time=0.02 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=635.830, Time=0.04 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=637.813, Time=0.10 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=634.715, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=634.623, Time=0.07 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=636.202, Time=0.29 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[12]
# Total fit time: 1.189 seconds

# %%
test = monthly_resampled_data.iloc[40:]
forecaste = model.predict(n_periods= 12)
test['forecast'] = forecaste
plt.plot(monthly_resampled_data)
plt.plot(test['forecast'], color = 'red',ls = 'dashed')
plt.legend(["Billing_amount","Forecasted_Billing_amount_auto_ARIMA"])
plt.xlabel('Year')
plt.ylabel('Billing_amount')
# Out:
# Text(0, 0.5, 'Billing_amount')

# %%
results_ARIMA.aic
# Out:
# 632.4939333263395

# %%
results_SARIMA.aic
# Out:
# 463.29329261619955

# %% [markdown]
# Forcasting by using SARIMA model with lower aic 463.29 is better than Arima model with aic 632.49.
#
# Forecasting: Billing amount for all the ages will remain constant in the future.
